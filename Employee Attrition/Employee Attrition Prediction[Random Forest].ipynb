# %%
import pandas as pd
import numpy as np

df = pd.read_csv("C:\\Users\\HP\\Downloads\\employeeattrition\\HR-Employee-Attrition.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# # EDA

# %%
df.Age.hist()

# %%
df.shape
# Out:
# (1470, 35)

# %%
#Checking for statistical values of the columns in the dataframe
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.HourlyRate.hist()

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.Attrition.value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
import seaborn as sns

sns.countplot(df["Attrition"])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,8))
sns.countplot(x="Age",hue="Attrition",data =df,palette ="colorblind")

# %% [markdown]
# We can notice clearly that there is higher attrition amount age groups of 24 -32

# %%
temp = pd.DataFrame()
temp["colnames"]=df.columns
temp["No of factors"]=df.nunique().tolist()
temp["DTYPE"]=df.dtypes.tolist()
temp
# Out:
#                     colnames  No of factors   DTYPE
# 0                        Age             43   int64
# 1                  Attrition              2  object
# 2             BusinessTravel              3  object
# 3                  DailyRate            886   int64
# 4                 Department              3  object
# 5           DistanceFromHome             29   int64
# 6                  Education              5   int64
# 7             EducationField              6  object
# 8              EmployeeCount              1   int64
# 9             EmployeeNumber           1470   int64
# 10   EnvironmentSatisfaction              4   int64
# 11                    Gender              2  object
# 12                HourlyRate             71   int64
# 13            JobInvolvement              4   int64
# 14                  JobLevel              5   int64
# 15                   JobRole              9  object
# 16           JobSatisfaction              4   int64
# ...

# %%
#Remove some useless columns
df.drop(["Over18","EmployeeNumber","StandardHours","EmployeeCount"],axis=1,inplace=True)

# %%
# Correlation
plt.figure(figsize=(18,18))
sns.heatmap(df.corr(),annot=True,fmt =".0%")

# %%
#Transform the data
#Transform non-numerical into numerical cols

from sklearn.preprocessing import LabelEncoder
for col in df.columns:
    if df[col].dtype ==np.number:
        continue
    df[col] = LabelEncoder().fit_transform(df[col])

# %%
#Splitting the data 

from sklearn.model_selection import train_test_split

X = df.drop("Attrition",1)
y= df["Attrition"].values
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)

# %%
# Use RandomForestClassifier

from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(n_estimators=10,criterion = "entropy",random_state =0)

forest.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
# Get the accuracy on the training set

forest.score(x_train,y_train)
# Out:
# 0.9782214156079855

# %%
#Show the confusion matrix and accuracy score for the model on the test data

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,forest.predict(x_test))
cm

TN =cm[0][0]
TP =cm[1][1]
FN =cm[1][0]
FP =cm[0][1]

print(cm)
print("Model Testing Accuracy ={}".format((TP+TN)/(TP+TN+FN+FP)))
# Out:
# [[308   2]
#  [ 51   7]]
# Model Testing Accuracy =0.8559782608695652
